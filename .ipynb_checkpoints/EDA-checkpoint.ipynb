# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
directory_name = "Cleaned_data"

if not os.path.exists(directory_name):
    os.makedirs(directory_name)

# %%
path = 'Cleaned_data'

csv_files = [os.path.join(path, f) for f in os.listdir(path) if f.endswith('.csv')]

dfs = [pd.read_csv(f) for f in csv_files]

# Merging the dataframes on the 'DATE' column
df_final = pd.concat(dfs, ignore_index=False).groupby('DATE').sum()

# %%
df_final.head()
# Out:
#             all_Const_Emp  emratio        GDP  home_ow_rate  house_st  income  \
# DATE
# 2003-07-01            0.0      0.0  11566.669          68.4       0.0     0.0
# 2003-08-01          840.2     62.1  11566.669          68.4    1833.0  9538.8
# 2003-08-08            0.0      0.0      0.000           0.0       0.0     0.0
# 2003-08-15            0.0      0.0      0.000           0.0       0.0     0.0
# 2003-08-22            0.0      0.0      0.000           0.0       0.0     0.0
#
#             IPI_Cement  labor_percent  monthly_supply  mortgage_rate  ...  \
# DATE                                                                  ...
# 2003-07-01       0.000            0.0             0.0           0.00  ...
# 2003-08-01     152.498           66.1             3.5           6.14  ...
# 2003-08-08       0.000            0.0             0.0           6.34  ...
# 2003-08-15       0.000            0.0             0.0           6.24  ...
# 2003-08-22       0.000            0.0             0.0           6.28  ...
#
#             new_private_house  new_private_hw_under  permit       POP  \
# DATE
# 2003-07-01                0.0                   0.0     0.0       0.0
# 2003-08-01             1570.0                1102.0  1966.0  291072.0
# 2003-08-08                0.0                   0.0     0.0       0.0
# 2003-08-15                0.0                   0.0     0.0       0.0
# 2003-08-22                0.0                   0.0     0.0       0.0
#
#             PPI_Cement  PPI_Concrete  p_saving_rate   target  total_emp_cons  \
# DATE
# 2003-07-01         0.0           0.0            0.0    0.000             0.0
# 2003-08-01         0.0         154.4            5.7  135.966          6760.0
# 2003-08-08         0.0           0.0            0.0    0.000             0.0
# 2003-08-15         0.0           0.0            0.0    0.000             0.0
# 2003-08-22         0.0           0.0            0.0    0.000             0.0
#
#             unemployed_rate
# DATE
# 2003-07-01              0.0
# 2003-08-01              6.1
# 2003-08-08              0.0
# 2003-08-15              0.0
# 2003-08-22              0.0
#
# [5 rows x 21 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1253 entries, 2003-07-01 to 2023-08-01
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   all_Const_Emp         1253 non-null   float64
#  1   emratio               1253 non-null   float64
#  2   GDP                   1253 non-null   float64
#  3   home_ow_rate          1253 non-null   float64
#  4   house_st              1253 non-null   float64
#  5   income                1253 non-null   float64
#  6   IPI_Cement            1253 non-null   float64
#  7   labor_percent         1253 non-null   float64
#  8   monthly_supply        1253 non-null   float64
#  9   mortgage_rate         1253 non-null   float64
#  10  MSPUS                 1253 non-null   float64
#  11  new_private_house     1253 non-null   float64
#  12  new_private_hw_under  1253 non-null   float64
#  13  permit                1253 non-null   float64
#  14  POP                   1253 non-null   float64
#  15  PPI_Cement            1253 non-null   float64
#  16  PPI_Concrete          1253 non-null   float64
#  17  p_saving_rate         1253 non-null   float64
#  18  target                1253 non-null   float64
#  19  total_emp_cons        1253 non-null   float64
#  20  unemployed_rate       1253 non-null   float64
# dtypes: float64(21)
# memory usage: 215.4+ KB

# %%
df_final.describe()
# Out:
#        all_Const_Emp      emratio           GDP  home_ow_rate     house_st  \
# count    1253.000000  1253.000000   1253.000000   1253.000000  1253.000000
# mean      149.631365    11.562251   3403.120515     12.723065   238.268156
# std       312.703446    23.717358   7194.789456     26.094459   526.979853
# min         0.000000     0.000000      0.000000      0.000000     0.000000
# 25%         0.000000     0.000000      0.000000      0.000000     0.000000
# 50%         0.000000     0.000000      0.000000      0.000000     0.000000
# 75%         0.000000     0.000000      0.000000      0.000000     0.000000
# max      1022.000000    63.400000  27623.543000     69.200000  2273.000000
#
#              income   IPI_Cement  labor_percent  monthly_supply  \
# count   1253.000000  1253.000000    1253.000000     1253.000000
# mean    2901.301995    21.596037      12.292019        1.202713
# std     6168.709977    46.055619      25.208188        2.606482
# min        0.000000     0.000000       0.000000        0.000000
# 25%        0.000000     0.000000       0.000000        0.000000
# 50%        0.000000     0.000000       0.000000        0.000000
# 75%        0.000000     0.000000       0.000000        0.000000
# max    24471.800000   192.032200      66.400000       12.200000
#
#        mortgage_rate  ...  new_private_house  new_private_hw_under  \
# count    1253.000000  ...        1253.000000           1253.000000
# mean        3.922610  ...         230.117318            197.076616
# std         2.041753  ...         506.007292            433.502312
# min         0.000000  ...           0.000000              0.000000
# 25%         3.370000  ...           0.000000              0.000000
# 50%         4.140000  ...           0.000000              0.000000
# 75%         5.630000  ...           0.000000              0.000000
# max         7.080000  ...        2245.000000           1710.000000
#
#             permit            POP   PPI_Cement  PPI_Concrete  p_saving_rate  \
# count  1253.000000    1253.000000  1253.000000   1253.000000    1253.000000
# mean    249.830806   60711.191352    28.802368     41.542209       1.135196
# std     552.138574  124588.985951    61.019965     87.315186       2.796886
# min       0.000000       0.000000     0.000000      0.000000       0.000000
# 25%       0.000000       0.000000     0.000000      0.000000       0.000000
# 50%       0.000000       0.000000     0.000000      0.000000       0.000000
# 75%       0.000000       0.000000     0.000000      0.000000       0.000000
# max    2263.000000  335413.676000   237.179000    336.455000      32.000000
#
#             target  total_emp_cons  unemployed_rate
# count  1253.000000     1253.000000      1253.000000
# mean     35.804912     1312.037510         1.140623
# std      76.085923     2710.927561         2.508870
# min       0.000000        0.000000         0.000000
# 25%       0.000000        0.000000         0.000000
# 50%       0.000000        0.000000         0.000000
# 75%       0.000000        0.000000         0.000000
# max     311.499000     7997.000000        14.700000
#
# [8 rows x 21 columns]

# %%
plt.figure(figsize=(12, 6))
for col in df_final.columns.tolist():
    plt.figure(figsize=(6, 4))
    sns.displot(data=df_final, x=col, kde =True)
    plt.xlabel(f"{col}")
    plt.ylabel("Count")
    plt.title(f'Distribution Plot for {col}')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
for col in df_final.columns.tolist():
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df_final, x=col)
    plt.xlabel(f"{col}")
    plt.title(f'Box Plot for {col}')
    plt.show()

# %%
df_final['p_saving_rate'].skew()
# Out:
# 3.862993289600251

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["p_saving_rate"].quantile(0.25)
q2 = df_final["p_saving_rate"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.0
# 0.0
# (None, None)

# %%
# capping the features to upper boundry only.
df_final.loc[df_final['p_saving_rate'] >=upper_bridge,'p_saving_rate'] = upper_bridge

# %%
df_final['p_saving_rate'].hist()
plt.title("Distribution of Personal Saving rate after handling outliers")
plt.xlabel("p_saving_rate")
plt.ylabel("Count")
plt.show()

# %%
df_final['PPI_Concrete'].skew()
# Out:
# 1.7650046839356066

# %%
df_final['PPI_Concrete'] = np.log1p(df_final['PPI_Concrete'])

# %%
df_final['PPI_Concrete'].hist()
# Out:
# <Axes: >

# %%
plt.boxplot(df_final['PPI_Concrete'], vert=False)
plt.xlabel('PPI_Concrete')
plt.title('Box Plot of PPI_Concrete')
plt.show()

# %%
df_final['new_private_house'].skew()
# Out:
# 2.0580433940740033

# %%
from scipy import stats

transformed_data, lambda_value = stats.yeojohnson(df_final['new_private_house'])
df_final['new_private_house'] = transformed_data

# %%
plt.boxplot(df_final['new_private_house'], vert=False)
plt.xlabel('new_private_house')
plt.title('Box Plot of new_private_house')
plt.show()

# %%
max_value = df_final['new_private_house'].max()

df_final['new_private_house'] = np.where(df_final['new_private_house'] > max_value, max_value, df_final['new_private_house'])

# %%
df_final['emratio'].skew()
# Out:
# 1.5677280936573579

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["emratio"].quantile(0.25)
q2 = df_final["emratio"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.0
# 0.0
# (None, None)

# %%
df_final.loc[df_final['emratio'] <=lower_bridge,'emratio'] = lower_bridge

# %%
plt.boxplot(df_final['emratio'], vert=False)
plt.xlabel('emratio')
plt.title('Box Plot of emratio')
plt.show()

# %%
df_final['new_private_hw_under'].skew()
# Out:
# 2.0081857071513056

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["new_private_hw_under"].quantile(0.25)
q2 = df_final["new_private_hw_under"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.0
# 0.0
# (None, None)

# %%
df_final.loc[df_final['new_private_hw_under'] >=upper_bridge,'new_private_hw_under'] = upper_bridge

# %%
plt.boxplot(df_final['new_private_hw_under'], vert=False)
plt.xlabel('new_private_hw_under')
plt.title('Box Plot of new_private_hw_under')
plt.show()

# %%
df_final['monthly_supply'].skew()
# Out:
# 2.0075066879194408

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["monthly_supply"].quantile(0.25)
q2 = df_final["monthly_supply"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.0
# 0.0
# (None, None)

# %%
df_final.loc[df_final['monthly_supply'] >=upper_bridge,'monthly_supply'] = upper_bridge

# %%
df_final['monthly_supply'].hist()
# Out:
# <Axes: >

# %%
df_final['unemployed_rate'].skew()
# Out:
# 2.1310728570034065

# %%
#finding the Q1(25 percentile) and Q3(75 percentile)
q1 = df_final["unemployed_rate"].quantile(0.25)
q2 = df_final["unemployed_rate"].quantile(0.75)

IQR =q2-q1

# %%
lower_bridge=q1-(IQR*1.5)
upper_bridge=q2+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 0.0
# 0.0
# (None, None)

# %%
df_final.loc[df_final['unemployed_rate'] >=upper_bridge,'unemployed_rate'] = upper_bridge

# %%
plt.boxplot(df_final['unemployed_rate'], vert=False)
plt.xlabel('unemployed_rate')
plt.title('Box Plot of unemployed_rate')
plt.show()

# %%
corr_matrix= df_final.corr()
corr_matrix['target'].sort_values(ascending=False)
# Out:
# target                  1.000000
# income                  0.990374
# MSPUS                   0.988197
# PPI_Cement              0.987080
# GDP                     0.984279
# total_emp_cons          0.980508
# all_Const_Emp           0.974058
# PPI_Concrete            0.972741
# POP                     0.972183
# new_private_house       0.964954
# emratio                 0.963512
# labor_percent           0.960282
# home_ow_rate            0.954200
# permit                  0.935462
# house_st                0.931859
# IPI_Cement              0.915376
# mortgage_rate          -0.748894
# monthly_supply               NaN
# new_private_hw_under         NaN
# p_saving_rate                NaN
# unemployed_rate              NaN
# Name: target, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["feature"] = df_final.columns

vif_data["VIF"] = [variance_inflation_factor(df_final.values, i)
                          for i in range(len(df_final.columns))]

print(vif_data)
# Out:
# C:\Users\rakshpan\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
#                  feature            VIF
# 0          all_Const_Emp    7910.634337
# 1                emratio   12646.856864
# 2                    GDP    1830.211889
# 3           home_ow_rate     816.787060
# 4               house_st     360.710198
# 5                 income    1667.660308
# 6             IPI_Cement     345.251504
# 7          labor_percent  107978.648069
# 8         monthly_supply            NaN
# 9          mortgage_rate       1.005797
# 10                 MSPUS    1133.879535
# 11     new_private_house  346810.324320
# 12  new_private_hw_under            NaN
# 13                permit     368.631308
# 14                   POP  118289.722994
# 15            PPI_Cement     188.841161
# 16          PPI_Concrete   68509.025892
# 17         p_saving_rate            NaN
# 18                target    1631.340730
# 19        total_emp_cons   11230.523750
# 20       unemployed_rate            NaN

# %%
df_final.to_csv("df_final.csv")
